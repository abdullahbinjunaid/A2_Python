# %% [markdown]
# Q1:

# %%
class Queue:
    def ___init___(self):
        self.QueueArray = []
        Headpointer = 0
        Tailpointer = 0
        for i in range(100):
            self.QueueArray.append(-1)

class NewQueue:
    def ___init___(self):
        self.QueueArray = []
        self.Headpointer = -1
        self.Tailpointer = 0
        for i in range(100):
            self.QueueArray.append(-1)
TheQueue = NewQueue()
