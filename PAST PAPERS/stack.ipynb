# %% [markdown]
# Q1 : 9618/42/O/N/23

# %%
global StackVowel 
global StackConsonant
StackVowel = []
StackConsonant = []
global VowelTop
global ConsonantTop

VowelTop = 0
ConsonantTop = 0 

def PushData(letter):
    global VowelTop
    global ConsonantTop
    if letter == "a" or "e" or "i" or "o" or "u" :
        if VowelTop == 100:
            print("stack Vowel is full")
        else:
            StackVowel.append(letter)
            VowelTop += 1
            print(f"{letter} added into the stack")
            print(StackVowel)
    else:
        if ConsonantTop == 100:
            print("StackConsonant full")
        else:
            StackConsonant.append(letter)
            ConsonantTop += 1
            print(f"{letter} added into the stack")
            print(StackConsonant)

def PopVowel():
    pass
def PopConsonant():
    pass
# Out:
# a added into the stack
# ['a']
