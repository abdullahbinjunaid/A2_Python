# %%
a= 6
b= 7
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 13
# -1
# 42
# 0.8571428571428571

# %%
a= 6
b= int(input("enter a number: "))

print("the answer is: ", a+b)
# Out:
# the answer is:  11

# %%
a = int(input("enter first number: "))
b = int(input("enter the secound number: "))
print(a**b)
# Out:
# 81

# %% [markdown]
# (**): operator is used to make exponent
# example: (num1**num2) will output the result num1^num2

# %%
a = int(input("enter first numbner: "))
b= int(input("enter secound number: "))
print(a%b)
# Out:
# 0

# %% [markdown]
# "%": operator is used to find the remainder when two numbers are divided by each other.

# %%
# 3 inputs and apply a formula
a = int(input("enter first number: "))
b = int(input("enter second number: "))
c = int(input("enter third number: "))

print(((a-b)/c)+(c/b))
# Out:
# 1.2083333333333333

# %%
salary1= (float(input("enter salary of last year: ")))
salary2= (float(input("enter salary of current year: ")))

print(((salary2-salary1)/salary1)*100,"%")
# Out:
# 40.0 %

# %% [markdown]
# to show increase in percentage : (new-original)/original * 100
