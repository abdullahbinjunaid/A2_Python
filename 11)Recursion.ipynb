# %% [markdown]
# # RECURSION

# %%
def factorial(n):
  # Base Case: if n is 0 or 1, return 1
  if n== 0 or n==1
    return 1
  # Recursive case: n * factorial(n-1)
  else:
    return n * factorial(n-1)

number = 5
result = factorial(number)
print(f"The factorial of {number} is {result}")
# Out:
# The factorial of 5 is 120

# %%
count = 0
def add():
  global num
  global count
  if count == 5:
    return num
  else:
    num = int(input("enter a number"))
    count = count + 1
    print(Total)
    Total += add()
    return Total
#num = int(input("enter a number"))
sum = add()
print(sum)
# Out:
# enter a number1
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# /tmp/ipython-input-3675673500.py in <cell line: 0>()
#      12     return Total
#      13 #num = int(input("enter a number"))
# ---> 14 sum = add()
#      15 print(sum)
#
# /tmp/ipython-input-3675673500.py in add()
#       8     num = int(input("enter a number"))
#       9     count = count + 1
# ---> 10     print(Total)
#      11     Total += add()
#      12     return Total
#
# UnboundLocalError: cannot access local variable 'Total' where it is not associated with a value

# %% [markdown]
# # **Stack**
# count = 1     n = 12     (f(1))
# count = 2     n = 12     (f(2))
# count = 3     n = 12     (f(3))
# f(4)= 0

# %%
count = 0
def total():
  global count
  if (count == 3):
    return 0
  else:
    n = int(input("Enter a value: "))
    count +=1
    return n + total()

print(total())
# Out:
# Enter a value: 5
# Enter a value: 5
# Enter a value: 5
# 15

# %%
def sum():
  num = int(input("enter a numer: "))
  if num == -1:
    return 0
  else:
    return num + sum()
print(sum())
# Out:
# enter a numer: 5
# enter a numer: 5
# enter a numer: 5
# enter a numer: 5
# enter a numer: 5
# enter a numer: 5
# enter a numer: 5
# enter a numer: 5
# enter a numer: -1
# 40
