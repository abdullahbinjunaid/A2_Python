# %% [markdown]
# # PRE-DEFINED FUNCTIONS

# %% [markdown]
# ### STRIP(), LSTRIP(), RSTRIP()

# %%
#strip() functipn removes any leading (spaces at the beginning) and trailing (spaces at the end) characters (space is the default leading character to remove)
x = "        my name is abdullah     "
x = x.strip()
print(x)
y = ".....eeeerrrr... abdullah .......eeerjjjj....."
y = y.strip(" .erj")
print(y)
# Out:
# my name is abdullah
# abdullah

# %%
text = " pppppppppppp      my name is abdullah bin junaid    .....lllkkkllll..."
text1 = text.rstrip(".lk ")
text2 = text.lstrip(" p")
print(text1)
print(text2)
# Out:
#  pppppppppppp      my name is abdullah bin junaid
# my name is abdullah bin junaid    .....lllkkkllll...

# %% [markdown]
# ### UPPER(), LOWER()

# %%
text3 = "abdullah bin junaid"
text2 = "ABDULLAH BIN JUNAID"
#UPPER() returns the string in captalize form
text = text3.upper()
#LOWER() returns the string in lower case form 
text4 = text2.lower()

print(text)
print(text4)
# Out:
# ABDULLAH BIN JUNAID
# abdullah bin junaid

# %% [markdown]
# ### CAPITALIZE()

# %%
#The capitalize() method returns a string where the first character is upper case, and the rest is lower case.
x = "abdullah"
print(x.capitalize())
# Out:
# Abdullah

# %% [markdown]
# ### SWAPCASE()

# %%
#The swapcase() method returns a string where all the upper case letters are lower case and vice versa.
y =  "AbduLLaH Bin JUnaid"
print(y.swapcase())
# Out:
# aBDUllAh bIN juNAID

# %% [markdown]
# ### FIND(), RFIND()

# %%
#The find() method finds the first occurrence of the specified value.
#The find() method returns -1 if the value is not found.
#The rfind() method finds the last occurrence of the specified value.
#The rfind() method returns -1 if the value is not found.
x = "My, name is abdullah bin junaid"
print(x.find("n"))
print(x.rfind("n"))
# Out:
# 4
# 27

# %% [markdown]
# ### SPLIT(), RSPLIT(), SPLITLINES()

# %%
#The split() method splits a string into a list.
#You can specify the separator, default separator is any whitespace.
x = "Hello i study in bcp gulshan"
print(x.split())
#you can specify which seperator needs to be split
y = "hello, i, study, in, college, "
print(y.split(", "))
#the number after comma will define the maximum times the string will be splitted
print(x.split(" ",2))
# Out:
# ['Hello', 'i', 'study', 'in', 'bcp', 'gulshan']
# ['hello', 'i', 'study', 'in', 'college', '']
# ['Hello', 'i', 'study in bcp gulshan']

# %%
#The rsplit() method splits a string into a list, starting from the right.
#If no "max" is specified, this method will return the same as the split() method.
txt = "apple, banana, cherry"
# setting the maxsplit parameter to 1, will return a list with 2 elements!
x = txt.rsplit(", ", 2)
z = txt.rsplit(", ", 1)
print(x)
print(z)
# note that the result has only 2 elements "apple, banana" is the first element, and "cherry" is the last.
y = txt.rsplit(", ")
print(y)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple, banana', 'cherry']
# ['apple', 'banana', 'cherry']

# %%
y = input("input a text ")

txt = "Thank you for the music\nWelcome to the jungle"

x = txt.splitlines()
z = y.splitlines()
print(x)
print(z)
# Out:
# ['Thank you for the music', 'Welcome to the jungle']
# ['Thank you for the music\\nWelcome to the jungle']
