# %% [markdown]
# # LINK LIST

# %%
#Adding a node from free list to the main list at the start, meaning from the start pointer.
def AddStrt(List,startpointer,emptyListpointer):
  temp = startpointer
  startpointer = emptyListpointer
  emptyListpointer = LinkedList[emptyListpointer].nextNode
  LinkedList[startpointer].nextNode = temp



class Node:
  def __init__(self, data, nextNode):
    self.data = data
    self.nextNode = nextNode

LinkedList = [Node(1,1),Node(5,4),Node(6,7),Node(7,-1),Node(2,2),Node(0,6),Node(0,8),Node(56,3),Node(0,9),Node(0,-1)]
startpointer = 0
emptyList = 5

Outputpointer = startpointer
print(f"Data : {LinkedList[Outputpointer].data} , Next Node : {LinkedList[Outputpointer].nextNode}")
Ncount = 1
while (LinkedList[Outputpointer].nextNode != -1):
  Outputpointer = LinkedList[Outputpointer].nextNode
  print(f"Data : {LinkedList[Outputpointer].data} , Next Node : {LinkedList[Outputpointer].nextNode}")
  Ncount += 1
print(Ncount)


epmtyListPointer = emptyList
print(f"Data : {LinkedList[epmtyListPointer].data} , Next Node : {LinkedList[Outputpointer].nextNode}")
Fcount = 1
while (LinkedList[epmtyListPointer].nextNode != -1):
  epmtyListPointer = LinkedList[epmtyListPointer].nextNode
  print(f"Data : {LinkedList[epmtyListPointer].data} , Next Node : {LinkedList[epmtyListPointer].nextNode}")
  Fcount += 1
print(Fcount)

#Adding a Node at the start of the linked list
AddStrt(LinkedList,startpointer,emptyList)

Outputpointer = startpointer
print(f"Data : {LinkedList[Outputpointer].data} , Next Node : {LinkedList[Outputpointer].nextNode}")
Ncount = 1
while (LinkedList[Outputpointer].nextNode != -1):
  Outputpointer = LinkedList[Outputpointer].nextNode
  print(f"Data : {LinkedList[Outputpointer].data} , Next Node : {LinkedList[Outputpointer].nextNode}")
  Ncount += 1
print(Ncount)


epmtyListPointer = emptyList
print(f"Data : {LinkedList[epmtyListPointer].data} , Next Node : {LinkedList[Outputpointer].nextNode}")
Fcount = 1
while (LinkedList[epmtyListPointer].nextNode != -1):
  epmtyListPointer = LinkedList[epmtyListPointer].nextNode
  print(f"Data : {LinkedList[epmtyListPointer].data} , Next Node : {LinkedList[epmtyListPointer].nextNode}")
  Fcount += 1
print(Fcount)
# Out:
# Data : 1 , Next Node : 1
# Data : 5 , Next Node : 4
# Data : 2 , Next Node : 2
# Data : 6 , Next Node : 7
# Data : 56 , Next Node : 3
# Data : 7 , Next Node : -1
# 6
# Data : 0 , Next Node : -1
# Data : 0 , Next Node : 8
# Data : 0 , Next Node : 9
# Data : 0 , Next Node : -1
# 4
# Data : 1 , Next Node : 1
# Data : 5 , Next Node : 4
# Data : 2 , Next Node : 2
# Data : 6 , Next Node : 7
# Data : 56 , Next Node : 3
# Data : 7 , Next Node : -1
# 6
# Data : 0 , Next Node : -1
# Data : 1 , Next Node : 1
# Data : 5 , Next Node : 4
# Data : 2 , Next Node : 2
# Data : 6 , Next Node : 7
# Data : 56 , Next Node : 3
# Data : 7 , Next Node : -1
# 7
