# %% [markdown]
# Q1:

# %%
txt =  "  apple, banana , cherry ,  date  "
x = txt.strip()
y = x.split(", ")
print(y)
for i in range(len(y)):
    print(y[i])
# Out:
# ['apple', 'banana ', 'cherry ', ' date']
# apple
# banana
# cherry
#  date

# %%
x =  "  apple, banana , cherry ,  date  "
x = txt.strip()
y = x.split(", ")
print(y)
for i in y:
    print(i)
# Out:
# ['apple', 'banana ', 'cherry ', ' date']
# apple
# banana
# cherry
#  date

# %%
x = 'apple'
for i in x:
    print(i)
# Out:
# a
# p
# p
# l
# e

# %% [markdown]
# Q2:

# %%
text = "Python is a powerful programming language."
if text.find("powerful") != -1:
    print("powerful found at index", text.find("powerful"))
else: 
    print("word powerful not found")
# Out:
# powerful found at index 12

# %% [markdown]
# Q3

# %%
data = "John|Alice|Bob|Maria"
x = data.split("|")
print(x)
print(x[1])
# Out:
# ['John', 'Alice', 'Bob', 'Maria']
# Alice

# %% [markdown]
# Q4

# %%
raw_data = "**Hello World!!!**"
print(raw_data.strip("*"))
# Out:
# Hello World!!!

# %% [markdown]
# Q5

# %%
paragraph = "Data science combines statistics, programming, and domain knowledge."
if paragraph.find("programming") != -1:
    print("word programming is found at index",paragraph.find("programming"))
else:
    print(paragraph.find("programming"))
# Out:
# word programming is found at index 34
